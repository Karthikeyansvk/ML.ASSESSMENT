# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikeyansvk/ML.ASSESSMENT/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/smart_grid_stability_augmented.csv')

# %%
df
# Out:
#            tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0      2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1      9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2      8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3      0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4      3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...         ...       ...       ...       ...       ...       ...       ...
# 39746  6.844700  4.659656  6.558959  1.174958  3.199371 -0.834139 -1.586567
# 39747  0.930871  2.309280  8.744054  3.660019  3.761953 -1.401607 -1.448435
# 39748  5.877214  7.910754  0.803602  3.037830  2.577958 -0.595308 -0.632792
# 39749  4.147708  9.033601  6.116851  6.755419  5.397039 -1.829268 -1.929091
# 39750  5.661965  7.803724       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39751 entries, 0 to 39750
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    39751 non-null  float64
#  1   tau2    39751 non-null  float64
#  2   tau3    39750 non-null  float64
#  3   tau4    39750 non-null  float64
#  4   p1      39750 non-null  float64
#  5   p2      39750 non-null  float64
#  6   p3      39750 non-null  float64
#  7   p4      39750 non-null  float64
#  8   g1      39750 non-null  float64
#  9   g2      39750 non-null  float64
#  10  g3      39750 non-null  float64
#  11  g4      39750 non-null  float64
#  12  stab    39750 non-null  float64
#  13  stabf   39750 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 4.2+ MB

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
df=df.copy()
df=df.drop('stab',axis=1)
y=df['stabf'].copy()
x=df.drop('stabf',axis=1).copy()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,shuffle=True,random_state=1)

# %%
x_train
# Out:
# array([[3.63358127, 2.4810672 , 8.1127402 , ..., 0.0547818 , 0.96511422,
#         0.08652371],
#        [4.57512751, 0.514421  , 2.08835865, ..., 0.7318012 , 0.12332692,
#         0.85494527],
#        [9.69534518, 0.57580326, 2.77789727, ..., 0.87983721, 0.49857699,
#         0.06722291],
#        ...,
#        [5.08524173, 1.79003062, 2.48639191, ..., 0.41851155, 0.32625269,
#         0.98248766],
#        [2.10380603, 7.83449257, 0.67800668, ..., 0.22353596, 0.74500479,
#         0.3398817 ],
#        [8.80989396, 8.86328127, 3.04196355, ..., 0.96554914, 0.18385105,
#         0.17163295]])

# %%
y_train
# Out:
# 27911      stable
# 2726       stable
# 16919      stable
# 36711    unstable
# 29967      stable
#            ...
# 7813       stable
# 32511    unstable
# 5192     unstable
# 12172      stable
# 33003    unstable
# Name: stabf, Length: 27825, dtype: object

# %%
clf=KNeighborsClassifier()
clf.fit(x_test, y_test)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy",format(clf.score(x_test,y_test)*100))
# Out:
# Accuracy 86.18983733020292
